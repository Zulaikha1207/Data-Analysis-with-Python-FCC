# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('medical_examination.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           70000 non-null  int64
#  1   age          70000 non-null  int64
#  2   gender       70000 non-null  int64
#  3   height       70000 non-null  int64
#  4   weight       70000 non-null  float64
#  5   ap_hi        70000 non-null  int64
#  6   ap_lo        70000 non-null  int64
#  7   cholesterol  70000 non-null  int64
#  8   gluc         70000 non-null  int64
#  9   smoke        70000 non-null  int64
#  10  alco         70000 non-null  int64
#  11  active       70000 non-null  int64
#  12  cardio       70000 non-null  int64
# dtypes: float64(1), int64(12)
# memory usage: 6.9 MB

# %%
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %% [markdown]
# #### Question1: Add an overweight column to the data. To determine if a person is overweight, first calculate their BMI by dividing their weight in kilograms by the square of their height in meters. If that value is > 25 then the person is overweight. Use the value 0 for NOT overweight and the value 1 for overweight.

# %%
df.weight.describe()
# Out:
# count    70000.000000
# mean        74.205690
# std         14.395757
# min         10.000000
# 25%         65.000000
# 50%         72.000000
# 75%         82.000000
# max        200.000000
# Name: weight, dtype: float64

# %%
#get height in meters
df['height_in_m'] = round((df['height'] / 100), 2)

# %%
#calculate BMI
df['BMI'] = round(df['weight'] / np.power(df['height_in_m'], 2), 1)

# %%
#calculate overweight based on BMI
df['overweight'] = np.where(df['BMI'] > 25, 1,0)
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio  height_in_m   BMI  overweight
# 0     0       1       0         1.68  22.0           0
# 1     0       1       1         1.56  34.9           1
# 2     0       0       1         1.65  23.5           0
# 3     0       1       1         1.69  28.7           1
# 4     0       0       0         1.56  23.0           0

# %% [markdown]
# #### Question2: Normalize the data by making 0 always good and 1 always bad. If the value of cholesterol or gluc is 1, make the value 0. If the value is more than 1, make the value 1.

# %%
df.cholesterol.value_counts()
# Out:
# 1    52385
# 2     9549
# 3     8066
# Name: cholesterol, dtype: int64

# %%
df.gluc.value_counts()
# Out:
# 1    59479
# 3     5331
# 2     5190
# Name: gluc, dtype: int64

# %%
df['cholesterol'] = np.where((df['cholesterol'] == 1), 0,1)
df['gluc'] = np.where((df['gluc'] == 1), 0,1)
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            0     0      0
# 1   1  20228       1     156    85.0    140     90            1     0      0
# 2   2  18857       1     165    64.0    130     70            1     0      0
# 3   3  17623       2     169    82.0    150    100            0     0      0
# 4   4  17474       1     156    56.0    100     60            0     0      0
#
#    alco  active  cardio  height_in_m   BMI  overweight
# 0     0       1       0         1.68  22.0           0
# 1     0       1       1         1.56  34.9           1
# 2     0       0       1         1.65  23.5           0
# 3     0       1       1         1.69  28.7           1
# 4     0       0       0         1.56  23.0           0

# %% [markdown]
# #### Question3: Convert the data into long format and create a chart that shows the value counts of the categorical features using seaborn's catplot(). The dataset should be split by 'Cardio' so there is one chart for each cardio value.

# %% [markdown]
# Side note: For data analysis having a wide format is usually better because each row denotes a unique observation. However, for plotting, long format is better as described
# <a href="https://www.statology.org/long-vs-wide-data/#:~:text=A%20dataset%20can%20be%20written,repeat%20in%20the%20first%20column."> here: </a>
# - "When to Use Long Format: As a rule of thumb, if you’re visualizing multiple variables in a plot using statistical software such as R you typically must convert your data to a long format in order for the software to create the plot"

# %%
#convert into long format using pd.melt()
df1 = df.reset_index()
df1 = pd.melt(df, id_vars='cardio', value_vars=['active', 'alco', 'cholesterol', 'gluc', 'overweight', 'smoke'], 
              var_name='health_metrics')
print(df1.head())
# Out:
#    cardio health_metrics  value
# 0       0         active      1
# 1       1         active      1
# 2       1         active      0
# 3       1         active      1
# 4       0         active      0

# %%
sns.catplot(x="health_metrics", kind="count", hue="value", 
            col="cardio", aspect=1.2, data=df1)

# %% [markdown]
# #### Question4: Clean the data. Filter out the following patient segments that represent incorrect data:

# %% [markdown]
# #### diastolic pressure is higher than systolic (Keep the correct data with (df['ap_lo'] <= df['ap_hi']))

# %%
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            0     0
# 1          1  20228       1     156    85.0    140     90            1     0
# 2          2  18857       1     165    64.0    130     70            1     0
# 3          3  17623       2     169    82.0    150    100            0     0
# 4          4  17474       1     156    56.0    100     60            0     0
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            0     0
# 69996  99995  22601       1     158   126.0    140     90            1     1
# 69997  99996  19066       2     183   105.0    180     90            1     0
# 69998  99998  22431       1     163    72.0    135     80            0     1
# 69999  99999  20540       1     170    72.0    120     80            1     0
#
#        smoke  alco  active  cardio  height_in_m   BMI  overweight
# 0          0     0       1       0         1.68  22.0           0
# 1          0     0       1       1         1.56  34.9           1
# 2          0     0       0       1         1.65  23.5           0
# 3          0     0       1       1         1.69  28.7           1
# 4          0     0       0       0         1.56  23.0           0
# ...      ...   ...     ...     ...          ...   ...         ...
# 69995      1     0       1       0         1.68  26.9           1
# 69996      0     0       1       1         1.58  50.5           1
# 69997      0     1       0       1         1.83  31.4           1
# 69998      0     0       0       1         1.63  27.1           1
# 69999      0     0       1       0         1.70  24.9           0
#
# [70000 rows x 16 columns]

# %%
df = df.loc[(df['ap_lo'] <= df['ap_hi'])]
df = df.reset_index()
df = df.drop('index', axis=1)
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            0     0
# 1          1  20228       1     156    85.0    140     90            1     0
# 2          2  18857       1     165    64.0    130     70            1     0
# 3          3  17623       2     169    82.0    150    100            0     0
# 4          4  17474       1     156    56.0    100     60            0     0
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 68761  99993  19240       2     168    76.0    120     80            0     0
# 68762  99995  22601       1     158   126.0    140     90            1     1
# 68763  99996  19066       2     183   105.0    180     90            1     0
# 68764  99998  22431       1     163    72.0    135     80            0     1
# 68765  99999  20540       1     170    72.0    120     80            1     0
#
#        smoke  alco  active  cardio  height_in_m   BMI  overweight
# 0          0     0       1       0         1.68  22.0           0
# 1          0     0       1       1         1.56  34.9           1
# 2          0     0       0       1         1.65  23.5           0
# 3          0     0       1       1         1.69  28.7           1
# 4          0     0       0       0         1.56  23.0           0
# ...      ...   ...     ...     ...          ...   ...         ...
# 68761      1     0       1       0         1.68  26.9           1
# 68762      0     0       1       1         1.58  50.5           1
# 68763      0     1       0       1         1.83  31.4           1
# 68764      0     0       0       1         1.63  27.1           1
# 68765      0     0       1       0         1.70  24.9           0
#
# [68766 rows x 16 columns]

# %% [markdown]
# #### height is less than the 2.5th percentile (Keep the correct data with (df['height'] >= df['height'].quantile(0.025)))

# %%
df = df.loc[(df['height'] >= df['height'].quantile(0.025))]
df = df.reset_index()
df = df.drop('index', axis=1)
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            0     0
# 1          1  20228       1     156    85.0    140     90            1     0
# 2          2  18857       1     165    64.0    130     70            1     0
# 3          3  17623       2     169    82.0    150    100            0     0
# 4          4  17474       1     156    56.0    100     60            0     0
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 67255  99993  19240       2     168    76.0    120     80            0     0
# 67256  99995  22601       1     158   126.0    140     90            1     1
# 67257  99996  19066       2     183   105.0    180     90            1     0
# 67258  99998  22431       1     163    72.0    135     80            0     1
# 67259  99999  20540       1     170    72.0    120     80            1     0
#
#        smoke  alco  active  cardio  height_in_m   BMI  overweight
# 0          0     0       1       0         1.68  22.0           0
# 1          0     0       1       1         1.56  34.9           1
# 2          0     0       0       1         1.65  23.5           0
# 3          0     0       1       1         1.69  28.7           1
# 4          0     0       0       0         1.56  23.0           0
# ...      ...   ...     ...     ...          ...   ...         ...
# 67255      1     0       1       0         1.68  26.9           1
# 67256      0     0       1       1         1.58  50.5           1
# 67257      0     1       0       1         1.83  31.4           1
# 67258      0     0       0       1         1.63  27.1           1
# 67259      0     0       1       0         1.70  24.9           0
#
# [67260 rows x 16 columns]

# %% [markdown]
# #### height is more than the 97.5th percentile

# %%
df = df.loc[(df['height'] <= df['height'].quantile(0.975))]
df = df.reset_index()
df = df.drop('index', axis=1)
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            0     0
# 1          1  20228       1     156    85.0    140     90            1     0
# 2          2  18857       1     165    64.0    130     70            1     0
# 3          3  17623       2     169    82.0    150    100            0     0
# 4          4  17474       1     156    56.0    100     60            0     0
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 65854  99992  21074       1     165    80.0    150     80            0     0
# 65855  99993  19240       2     168    76.0    120     80            0     0
# 65856  99995  22601       1     158   126.0    140     90            1     1
# 65857  99998  22431       1     163    72.0    135     80            0     1
# 65858  99999  20540       1     170    72.0    120     80            1     0
#
#        smoke  alco  active  cardio  height_in_m   BMI  overweight
# 0          0     0       1       0         1.68  22.0           0
# 1          0     0       1       1         1.56  34.9           1
# 2          0     0       0       1         1.65  23.5           0
# 3          0     0       1       1         1.69  28.7           1
# 4          0     0       0       0         1.56  23.0           0
# ...      ...   ...     ...     ...          ...   ...         ...
# 65854      0     0       1       1         1.65  29.4           1
# 65855      1     0       1       0         1.68  26.9           1
# 65856      0     0       1       1         1.58  50.5           1
# 65857      0     0       0       1         1.63  27.1           1
# 65858      0     0       1       0         1.70  24.9           0
#
# [65859 rows x 16 columns]

# %% [markdown]
# #### weight is less than the 2.5th percentile

# %%
df = df.loc[(df['weight'] >= df['weight'].quantile(0.025))]
df = df.reset_index()
df = df.drop('index', axis=1)
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            0     0
# 1          1  20228       1     156    85.0    140     90            1     0
# 2          2  18857       1     165    64.0    130     70            1     0
# 3          3  17623       2     169    82.0    150    100            0     0
# 4          4  17474       1     156    56.0    100     60            0     0
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 64379  99992  21074       1     165    80.0    150     80            0     0
# 64380  99993  19240       2     168    76.0    120     80            0     0
# 64381  99995  22601       1     158   126.0    140     90            1     1
# 64382  99998  22431       1     163    72.0    135     80            0     1
# 64383  99999  20540       1     170    72.0    120     80            1     0
#
#        smoke  alco  active  cardio  height_in_m   BMI  overweight
# 0          0     0       1       0         1.68  22.0           0
# 1          0     0       1       1         1.56  34.9           1
# 2          0     0       0       1         1.65  23.5           0
# 3          0     0       1       1         1.69  28.7           1
# 4          0     0       0       0         1.56  23.0           0
# ...      ...   ...     ...     ...          ...   ...         ...
# 64379      0     0       1       1         1.65  29.4           1
# 64380      1     0       1       0         1.68  26.9           1
# 64381      0     0       1       1         1.58  50.5           1
# 64382      0     0       0       1         1.63  27.1           1
# 64383      0     0       1       0         1.70  24.9           0
#
# [64384 rows x 16 columns]

# %% [markdown]
# #### weight is more than the 97.5th percentile

# %%
df = df.loc[(df['weight'] <= df['weight'].quantile(0.975))]
df = df.reset_index()
df = df.drop('index', axis=1)
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            0     0
# 1          1  20228       1     156    85.0    140     90            1     0
# 2          2  18857       1     165    64.0    130     70            1     0
# 3          3  17623       2     169    82.0    150    100            0     0
# 4          4  17474       1     156    56.0    100     60            0     0
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 62779  99991  19699       1     172    70.0    130     90            0     0
# 62780  99992  21074       1     165    80.0    150     80            0     0
# 62781  99993  19240       2     168    76.0    120     80            0     0
# 62782  99998  22431       1     163    72.0    135     80            0     1
# 62783  99999  20540       1     170    72.0    120     80            1     0
#
#        smoke  alco  active  cardio  height_in_m   BMI  overweight
# 0          0     0       1       0         1.68  22.0           0
# 1          0     0       1       1         1.56  34.9           1
# 2          0     0       0       1         1.65  23.5           0
# 3          0     0       1       1         1.69  28.7           1
# 4          0     0       0       0         1.56  23.0           0
# ...      ...   ...     ...     ...          ...   ...         ...
# 62779      0     0       1       1         1.72  23.7           0
# 62780      0     0       1       1         1.65  29.4           1
# 62781      1     0       1       0         1.68  26.9           1
# 62782      0     0       0       1         1.63  27.1           1
# 62783      0     0       1       0         1.70  24.9           0
#
# [62784 rows x 16 columns]

# %% [markdown]
# #### Q5: Create a correlation matrix using the dataset. Plot the correlation matrix using seaborn's heatmap(). Mask the upper triangle.

# %%
#drop height in meter column
df = df.drop('height_in_m', axis=1)

# Compute the correlation matrix
corr = df.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
#cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask,  vmax=.3, center=0, annot=True, fmt='.1f',
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>
